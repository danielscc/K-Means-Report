# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('happyscore_income.csv')
data
# Out:
#                 country  adjusted_satisfaction  avg_satisfaction  \
# 0               Armenia                   37.0               4.9
# 1                Angola                   26.0               4.3
# 2             Argentina                   60.0               7.1
# 3               Austria                   59.0               7.2
# 4             Australia                   65.0               7.6
# 5            Azerbaijan                   46.0               5.8
# 6            Bangladesh                   43.0               5.3
# 7               Belgium                   63.0               7.2
# 8          Burkina Faso                   37.0               4.4
# 9              Bulgaria                   34.0               4.6
# 10              Burundi                   25.0               2.9
# 11                Benin                   20.0               3.0
# 12              Bolivia                   53.0               6.3
# ...

# %%
data.sort_values('avg_income', ascending="True", inplace=True)

bottom_gdp = data[ data['avg_income'] < 1500 ] #filter

bottom_gdp
# Out:
#           country  adjusted_satisfaction  avg_satisfaction  std_satisfaction  \
# 10        Burundi                   25.0               2.9              1.96
# 65     Madagascar                   33.0               3.7              1.86
# 58        Liberia                   37.0               4.4              2.02
# 72     Mozambique                   34.0               3.8              1.76
# 73          Niger                   34.0               3.8              1.75
# 93   Sierra Leone                   27.0               3.5              2.36
# 8    Burkina Faso                   37.0               4.4              2.02
# 66           Mali                   32.0               4.7              2.90
# 59        Lesotho                   40.0               5.2              2.49
# 74        Nigeria                   43.0               5.3              2.19
# 97           Togo                   22.0               2.6              2.08
# ...

# %%
plt.scatter(bottom_gdp['avg_income'],bottom_gdp['happyScore'])
plt.scatter(bottom_gdp['avg_income'],bottom_gdp['happyScore'])
europe = bottom_gdp[ bottom_gdp['region'] = "Central and Eastern Europe" ]
